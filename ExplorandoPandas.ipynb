# %%
import pandas as pd

# %%
faturas = pd.read_table("Sanduiches.txt")

# %%
faturas.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
usuarios = pd.read_table('Users.txt', sep='|')

# %%
usuarios.head()
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
usuarios = pd.read_table('Users.txt', sep='|', header=None)

# %%
usuarios.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
colunas = ['id','idade','sexo','profissao','cep']
usuarios = pd.read_table('Users.txt', sep='|', header=None, names=colunas)

# %%
usuarios.head()
# Out:
#    id  idade sexo   profissao    cep
# 0   1     24    M  technician  85711
# 1   2     53    F       other  94043
# 2   3     23    M      writer  32067
# 3   4     24    M  technician  43537
# 4   5     33    F       other  15213

# %%
ufo = pd.read_csv('ufo.csv')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df = pd.read_fwf('LarguraFixa.txt')
df
# Out:
#          USAF   WBAN             STATION NAME CTRY   ST  CALL     LAT  \
# 0        7005  99999               CWOS 07005  NaN  NaN   NaN     NaN
# 1        7011  99999               CWOS 07011  NaN  NaN   NaN     NaN
# 2        7018  99999               WXPOD 7018  NaN  NaN   NaN   0.000
# 3        7025  99999               CWOS 07025  NaN  NaN   NaN     NaN
# 4        7026  99999               WXPOD 7026   AF  NaN   NaN   0.000
# 5        7034  99999               CWOS 07034  NaN  NaN   NaN     NaN
# 6        7037  99999               CWOS 07037  NaN  NaN   NaN     NaN
# 7        7044  99999               CWOS 07044  NaN  NaN   NaN     NaN
# 8        7047  99999               CWOS 07047  NaN  NaN   NaN     NaN
# 9        7052  99999               CWOS 07052  NaN  NaN   NaN     NaN
# 10       7059  99999               CWOS 07059  NaN  NaN   NaN     NaN
# 11       7064  99999               CWOS 07064  NaN  NaN   NaN     NaN
# ...

# %%
regex = '\s+'
df = pd.read_csv('SepEspaco.txt', sep=regex)
df.head()
# Out:
#    Year  Month  Day  Hour  Temp  DewTemp  Pressure  WindDir  WindSpeed  Sky  \
# 0  1912      4    1     6   114       94     10121      200        120    8
# 1  1912      4    1     9   146       96     10122      240        140    8
# 2  1912      4    2     6   172      122     10146      210         40    2
# 3  1912      4    2     9   193    -9999     10150      240        210    1
# 4  1912      4    2    12   188      125     10152      240        250    1
#
#    Precip1  Precip6
# 0    -9999    -9999
# 1    -9999    -9999
# 2    -9999       40
# 3    -9999        0
# 4    -9999        0

# %%
arquivo = open('/Users/igomes/Documents/DataScience/raw/teste.txt','w')
arquivo.write('alguma coisa escrita aqui')
arquivo.close()
arquivo = open('/Users/igomes/Documents/DataScience/raw/teste.txt','a')
arquivo.write('escrevendo uma nova linha\n')
arquivo.close()
